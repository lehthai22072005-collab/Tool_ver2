# %% [markdown]
# # Stage 2 PhoBERT training
# This notebook is used only to attach the VS Code Colab extension to a GPU runtime.

# %%
import torch
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NO GPU')
